# %%
#importing relevant packages

import numpy as np
import pandas as pd

# %%
# reading the cohort file from step 1
df_cohort_step2 = pd.read_csv("/Users/abdullahhasib/Documents/application file/NUS/courses/semester 2/SPH6004 Advanced Statistical Learning/group assignment/SPH6004-group-assignment/cohort.csv")

df_cohort_step2.head()
# Out:
#    subject_id   hadm_id   stay_id  \
# 0    10001217  24597018  37067082
# 1    10001725  25563031  31205490
# 2    10001884  26184834  37510196
# 3    10002013  23581541  39060235
# 4    10002155  23822395  33685454
#
#                                      first_careunit  \
# 0               Surgical Intensive Care Unit (SICU)
# 1  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 2                Medical Intensive Care Unit (MICU)
# 3      Cardiac Vascular Intensive Care Unit (CVICU)
# 4                          Coronary Care Unit (CCU)
#
#                                       last_careunit  icu_los_hours  \
# 0               Surgical Intensive Care Unit (SICU)      26.832778
# 1  Medical/Surgical Intensive Care Unit (MICU/SICU)      32.126111
# 2                Medical Intensive Care Unit (MICU)     220.123611
# 3      Cardiac Vascular Intensive Care Unit (CVICU)      31.544444
# 4                          Coronary Care Unit (CCU)     148.293889
#
#                 intime              outtime       los            deathtime  \
# 0  2157-11-20 19:18:02  2157-11-21 22:08:00  1.118032                  NaN
# 1  2110-04-11 15:52:22  2110-04-12 23:59:56  1.338588                  NaN
# 2  2131-01-11 04:20:05  2131-01-20 08:27:30  9.171817  2131-01-20 05:15:00
# 3  2160-05-18 10:00:53  2160-05-19 17:33:33  1.314352                  NaN
# 4  2129-08-04 12:45:00  2129-08-10 17:02:38  6.178912  2131-03-10 21:53:00
#
#    ...  ggt_min ggt_max ld_ldh_min ld_ldh_max so2_min  so2_max  po2_min  \
# 0  ...      NaN     NaN        NaN        NaN     NaN      NaN      NaN
# 1  ...      NaN     NaN        NaN        NaN     NaN      NaN      NaN
# 2  ...      NaN     NaN        NaN        NaN     NaN      NaN     40.0
# 3  ...      NaN     NaN        NaN        NaN     NaN      NaN     90.0
# 4  ...      NaN     NaN      507.0      507.0     NaN      NaN     76.0
#
#   po2_max  radiology_note_count  hours_to_death
# 0     NaN                     1             NaN
# 1     NaN                     1             NaN
# 2    49.0                    11      216.915278
# 3   462.0                     1             NaN
# 4    76.0                     4    14001.133333
#
# [5 rows x 143 columns]

# %%
# identify the value count for the target variable
df_cohort_step2["icu_death_flag"].value_counts()
# Out:
# icu_death_flag
# 0    37841
# 1     2616
# Name: count, dtype: int64

# %%
#description of the length of stay variable
df_cohort_step2["icu_los_hours"].describe()
# Out:
# count    40457.000000
# mean        97.893858
# std        126.631434
# min         24.001111
# 25%         35.921111
# 50%         55.108333
# 75%        101.221111
# max       2645.574722
# Name: icu_los_hours, dtype: float64

# %%
#creating a new column label_Y48 to indicate alive or dead in 48 hours. 

df_cohort_step2["label_Y48"] = (
    (df_cohort_step2["icu_death_flag"] == 0) &
    (df_cohort_step2["icu_los_hours"] <= 48)
).astype(int)

df_cohort_step2["label_Y48"].value_counts()
# Out:
# label_Y48
# 0    24289
# 1    16168
# Name: count, dtype: int64

# %%
#same thing but for 72 hours

df_cohort_step2["label_Y72"] = (
    (df_cohort_step2["icu_death_flag"] == 0) &
    (df_cohort_step2["icu_los_hours"] <= 72)
).astype(int)

df_cohort_step2["label_Y72"].value_counts()
# Out:
# label_Y72
# 1    24040
# 0    16417
# Name: count, dtype: int64

# %%
#exporting the cohort file into working directory for step 3
df_cohort_step2.to_csv("cohort_step_2.csv", index=False)
