# %%
#importing relevant packages

import numpy as np
import pandas as pd

# %%
df_cohort = pd.read_csv("/Users/abdullahhasib/Documents/application file/NUS/courses/semester 2/SPH6004 Advanced Statistical Learning/group assignment/SPH6004-group-assignment/cohort.csv")

df_cohort
